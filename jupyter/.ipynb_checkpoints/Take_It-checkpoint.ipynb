# %%
### 기계공학과 4학년
### 20154523 강남규

# %% [markdown]
# ## Take It

# %%
import pygame
from random import randrange

#색
black = (0,0,0)
white = (255,255,255)

point_list = ["plus.png", "minus.png"]
item_list = ["heal.png", "fast.png", "slow.png", "stop.png"]

#떨어지는 class
class Mask(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        
        rand_list = randrange(2)
        self.image = pygame.image.load(point_list[rand_list]).convert()
        self.image.set_colorkey(white)
        
        self.rect = self.image.get_rect()
        
        def reset_pos(self):
            self.rect.x = random.randrange(0,screen_width)
            self.rect.y = random.randrange(-130,-30)
            
        def update(self, change_y):
            self.rect.y += change_y
            if self.rect.y > screen_height:
                self.reset_pos()
                
class No_Mask(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        
        self.image = pygame.image.load("minus.png").convert()
        self.image.set_colorkey(white)
        
        self.rect = self.image.get_rect()
        
        def reset_pos(self):
            self.rect.x = random.randrange(0,screen_width)
            self.rect.y = random.randrange(-130,-30)
            
        def update(self, change_y):
            self.rect.y += change_y
            if self.rect.y > screen_height:
                self.reset_pos()
                

                

                
#pygame 초기화                
pygame.init()

#창 너비 지정 및 창크기 설정
screen_width = 800
screen_height = 600
screen = pygame.display.set_mode([screen_width,screen_height])
pygame.display.set_caption('Take It')

background = pygame.Surface(screen.get_size())
background.fill(black)
background_position=[0,0]

#이미지 및 사운드 load
background_image = pygame.image.load("library.jpg").convert()
player_image = pygame.image.load("hand.png").convert()
player_image.set_colorkey(white)

back_sound = pygame.mixer.Sound("backsound.wav")
eat_p_sound = pygame.mixer.Sound("eat_p.wav")
eat_m_sound = pygame.mixer.Sound("eat_m.wav")
hit_sound = pygame.mixer.Sound("hit.wav")
dead_sound = pygame.mixer.Sound("dead.wav")
heal_sound = pygame.mixer.Sound("Item_heal.wav")
slow_sound = pygame.mixer.Sound("Item_slow.wav")
fast_sound = pygame.mixer.Sound("Item_fast.wav")
stop_sound = pygame.mixer.Sound("Item_stop.wav")


block_list = pygame.sprite.Group()
all_sprites_list =pygame.sprite.Group()

for i in range(50):
    block = Block(black, 20, 15)
    block.rect.x = random.randrange(screen_width)
    block.rect.y = random.randrange(screen_height)
    block_list.add(block)
    all_sprites_list.add(block)
    
player = Block(red, 20, 15)
all_sprites_list.add(player)


clock = pygame.time.Clock()
done = False

#타이머
total_time = 10
start_ticks = pygame.time.get_ticks()

font = pygame.font.Font("malgun.ttf", 25)
score = 0
level = 1

while done == False:    
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            done=True
            
    screen.fill(white)
    pos = pygame.mouse.get_pos()
    player.rect.x = pos[0]
    player.rect.y = pos[1]
    
    blocks_hit_list = pygame.sprite.spritecollide(player, block_list, True)
    
    if len(blocks_hit_list) > 0:
        score += len(blocks_hit_list)
    
    if len(block_list) == 0:
        level += 1
        for i in range(level * 10):
            block = Block(black, 20, 15)
            block.rect.x = random.randrange(screen_width)
            block.rect.y = random.randrange(screen_height)
            block_list.add(block)
            all_sprites_list.add(block)
        
    all_sprites_list.draw(screen)
    text = font.render("점수: " + str(score), True, black)
    screen.blit(text, [10,10])
    text = font.render("레벨: " + str(level), True, black)
    screen.blit(text, [10,40])
    
    block_list.update(level)
    
     #경과시간 계산
    
    elapsed_time = (pygame.time.get_ticks() - start_ticks) / 1000
    
    timer = font.render("Level : " + str(int(T/10)) + " Timer: " + str(int(total_time - elapsed_time)), True, black)

    #경과 시간 표시
    screen.blit(screen, (0, 0))
    screen.blit(timer, (10, 10))
    
    
    
    clock.tick(20)
    pygame.display.flip()

pygame.quit()
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-e5a4e45da12d> in <module>
#      65
#      66 #이미지 및 사운드 load
# ---> 67 background_image = pygame.image.load("library.jpg").convert()
#      68 player_image = pygame.image.load("hand.png").convert()
#      69 player_image.set_colorkey(white)
#
# error: Couldn't open library.jpg
