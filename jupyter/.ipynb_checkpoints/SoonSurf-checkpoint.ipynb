# %%
### 기계공학과 4학년
### 20154523 강남규

# %% [markdown]
# ## 순천향 서핑대회

# %%
import sqlite3
from flask import Flask, render_template, request

app = Flask(__name__)


@app.route('/SoonSurf')
def surf():
    return render_template('loginForm.html')


@app.route('/login', methods=['POST'])
def login():
    idn = request.form['id']
    pwd = request.form['passwd']
    
    conn = sqlite3.connect('member.db')
    conn.row_factory = sqlite3.Row
    cursor = conn.cursor()
    
    cursor.execute('select * from meminfo where id =?', (idn,))
    row = cursor.fetchone()
    conn.close()

    if row != None:
        if idn == row['id'] and pwd == row['passwd']:
            return render_template('surfForm.html')
        
        return("<h2>로그인 에러 !!</h2>")



@app.route('/member', methods=['POST'])
def member():
    return render_template('memForm.html')



@app.route('/register', methods=['POST'])
def refister():
    import datetime
    
    idn = request.form['id']
    pwd = request.form['passwd']
    na = request.form['name']
    tm = datetime.datetime.now()
    
    conn = sqlite3.connect('member.db')
    cursor = conn.cursor()
    
    cursor.execute('''insert into meminfo (id, passwd, name, time) values(?, ?, ?, ?)''',
                   (idn,pwd,na,tm))
    conn.commit()
    conn.close()

    mstr = "id = %s, passwd = %s, name = %s, time = %s" % (idn, pwd, na, tm)
    outstr = "<h3>회원 가입이 되었습니다.</h3><hr><p>" + mstr

    return outstr



@app.route('/show', methods=['POST'])
def show():
    na = request.form['name']

    conn = sqlite3.connect('SoonSurf.db')
    conn.row_factory = sqlite3.Row
    cursor = conn.cursor()
    
    cursor.execute('''select * from surfinfo where name =?''', (na,))
    row = cursor.fetchone()
    
    conn.close()
    
    outstr = "<h2>선수 조회</h2><br><hr>"
    
    if row != None:
        outstr += "name: %s <br>" % row['name']
        outstr += "score: %s <br>" % row['score']
        outstr += "gender: %s <br>" % row['gender']
        outstr += "country: %s <br>" % row['country']
    else:
        outstr += "선수 데이터가 없습니다!!"
    
    return outstr



@app.route('/insert', methods=['POST'])
def insert():
    na = request.form['name']
    sc = request.form['score']
    gn = request.form['gender']
    ct = request.form['country']

    conn = sqlite3.connect('SoonSurf.db')
    cursor = conn.cursor()
    
    cursor.execute('''insert into surfinfo (name, score, gender, country) values(?, ?, ?, ?)''',
               (na, float(sc), gn, ct))
    conn.commit()
    conn.close()
    
    outstr = "<h2>선수 입력</h2><br><hr>"
    outstr += "name: %s <br>" % na
    outstr += "score: %s <br>" % sc
    outstr += "gender: %s <br>" % gn
    outstr += "country: %s <br>" % ct
    
    return outstr
       
    
    
if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [05/Oct/2020 10:21:27] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [05/Oct/2020 10:22:01] "GET /SoonSurf HTTP/1.1" 200 -
# [2020-10-05 10:22:03,861] ERROR in app: Exception on /login [POST]
# Traceback (most recent call last):
#   File "c:\users\kayal\appdata\local\programs\python\python38\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\users\kayal\appdata\local\programs\python\python38\lib\site-packages\flask\app.py", line 1953, in full_dispatch_request
#     return self.finalize_request(rv)
#   File "c:\users\kayal\appdata\local\programs\python\python38\lib\site-packages\flask\app.py", line 1968, in finalize_request
#     response = self.make_response(rv)
#   File "c:\users\kayal\appdata\local\programs\python\python38\lib\site-packages\flask\app.py", line 2097, in make_response
#     raise TypeError(
# TypeError: The view function did not return a valid response. The function either returned None or ended without a return statement.
# 127.0.0.1 - - [05/Oct/2020 10:22:03] "POST /login HTTP/1.1" 500 -
# 127.0.0.1 - - [05/Oct/2020 10:22:07] "POST /login HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Oct/2020 10:22:10] "POST /login HTTP/1.1" 200 -
# [2020-10-05 10:22:23,884] ERROR in app: Exception on /login [POST]
# Traceback (most recent call last):
#   File "c:\users\kayal\appdata\local\programs\python\python38\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\users\kayal\appdata\local\programs\python\python38\lib\site-packages\flask\app.py", line 1953, in full_dispatch_request
#     return self.finalize_request(rv)
#   File "c:\users\kayal\appdata\local\programs\python\python38\lib\site-packages\flask\app.py", line 1968, in finalize_request
#     response = self.make_response(rv)
#   File "c:\users\kayal\appdata\local\programs\python\python38\lib\site-packages\flask\app.py", line 2097, in make_response
#     raise TypeError(
# TypeError: The view function did not return a valid response. The function either returned None or ended without a return statement.
# 127.0.0.1 - - [05/Oct/2020 10:22:23] "POST /login HTTP/1.1" 500 -
